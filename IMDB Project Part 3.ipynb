# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *

# %%
# Create connection string using credentials
username = "root"
password = "root"
db_name = "movies"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
engine = create_engine(connection)

# %% [markdown]
# ## Create Database

# %%
# Check if the database exists. If not, create it.
if database_exists(connection) == False:
  create_database(connection)
else:
  print('The database already exists')
# Out:
# The database already exists

# %% [markdown]
# ## Load in Datasets
#
# There will be datasets being loaded to create the MySQL Database.

# %%
basics = pd.read_csv('Data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
ratings = pd.read_csv('Data/title_ratings.csv.gz')
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1953
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2587
# 3  tt0000006            5.1       177
# 4  tt0000007            5.4       812

# %%
tmdb_api = pd.read_csv('Data/tmdb_results_combined.csv.gz')
tmdb_api.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %% [markdown]
# ## Cleaning and Normalizing Datasets

# %% [markdown]
# Before I start dropping unnecessary columns from the 'basics' dataset, there are a couple of columns that I need to normalize and create joiner tables. For the 'genres' column, I want to make 2 tables named 'title_genres' and 'genres'. The 'genres' column in the 'basics' dataset contains a list of different genres the movie belongs to. This needs to be split into just a 'genres' table to make the data more efficient.

# %%
# view the column as a split list of strings
genres_split = basics['genres'].str.split(',')

# explode the series and find the unqiue values only
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Biography', 'Mystery', 'Musical', 'Action', 'Adventure', 'Crime',
#        'Thriller', 'Music', 'Animation', 'Family', 'History', 'War',
#        'Sport', 'Western', 'Adult', 'Short', 'Reality-TV', 'News',
#        'Talk-Show', 'Game-Show'], dtype=object)

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres                genres_split
# ...

# %%
# use .explode() to separate the list into new rows
exploded_genres = basics.explode('genres_split')
exploded_genres.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
#
#    runtimeMinutes                  genres genres_split
# ...

# %%
unique = sorted(exploded_genres['genres_split'].unique())

# %% [markdown]
# To create a new table, I will use the exploded 'basics' DataFrame.

# %%
basics_genres = exploded_genres[['tconst', 'genres_split']].copy()
basics_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %% [markdown]
# Now a mapper dictionary will be needed to replace string genres with integers. This will allow me to create a numeric id for the genres.

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique))
genre_map = dict(zip(unique, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
basics['genre_id'] = basics['genres_split'].replace(genre_map)
basics = basics.drop(columns='genres_split')

# %%
genres = pd.DataFrame({'genre_name': genre_map.keys(),
                            'genre_id': genre_map.values()})
genres.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# Now that all of the tables needed have been created for the database, I can clean the other datasets and then send the tables to the database.

# %% [markdown]
# ### 'Basics' Dataset

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres                    genre_id
# ...

# %%
basics = basics.drop(columns=['originalTitle', 'isAdult', 'titleType',
                             'genres', 'genre_id'])

# %%
basics.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold       2001
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...       2020
# 2  tt0069049                         The Other Side of the Wind       2018
# 3  tt0088751                                  The Naked Monster       2005
# 4  tt0096056                               Crime and Punishment       2002
#
#    endYear  runtimeMinutes
# 0      NaN             118
# 1      NaN              70
# 2      NaN             122
# 3      NaN             100
# 4      NaN             126

# %% [markdown]
# ### TMDB API Dataset
#
# I want to only keep a select number of columns in this dataset: movie_id, budget, revenue, and certification.

# %%
tmdb_api = tmdb_api[['imdb_id', 'budget', 'revenue', 'certification']]
tmdb_api.head()
# Out:
#      imdb_id      budget     revenue certification
# 0          0         NaN         NaN           NaN
# 1  tt0113026  10000000.0         0.0           NaN
# 2  tt0113092         0.0         0.0           NaN
# 3  tt0116391         0.0         0.0           NaN
# 4  tt0118694    150000.0  12854953.0            PG

# %% [markdown]
# I need to delete the row that does not have a imdb_id.

# %%
tmdb_api = tmdb_api.drop(0)
tmdb_api.head()
# Out:
#      imdb_id      budget     revenue certification
# 1  tt0113026  10000000.0         0.0           NaN
# 2  tt0113092         0.0         0.0           NaN
# 3  tt0116391         0.0         0.0           NaN
# 4  tt0118694    150000.0  12854953.0            PG
# 5  tt0118852         0.0         0.0             R

# %% [markdown]
# ## Add Tables to SQL Database

# %% [markdown]
# ### Saving 'tconst' as the Primary Key in 'basics'
#
# In order to save this column as the primary key, I need to provide the SQL datatype schema of the columns in the table. Since 'tconst' is a string, I need to tell it as such.

# %%
# Calculate max string lengths for object columns in 'basics'
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
# Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Calculate max string lengths for object columns in 'rating'
key_len = ratings['tconst'].fillna('').map(len).max()
# Create a schema dictonary using Sqlalchemy datatype objects
df_schema_ratings = {
    "tconst": String(key_len+1), 
    'averageRatings': Float(),
    'numVotes':Float()}

# %%
# Calculate max string lengths for object columns in 'tmdb_api'
key_len = tmdb_api['imdb_id'].fillna('').map(len).max()
cert_len = tmdb_api['certification'].fillna('').map(len).max()
# Create a schema dictonary using Sqlalchemy datatype objects
df_schema_tmdb = {
    "imdb_id": String(key_len+1), 
    'budget': Float(),
    'revenue':Float(),
    'certification': Text(title_len+1)}

# %%
# Calculate max string lengths for object columns in 'basics_genres'
key_len = basics_genres['tconst'].fillna('').map(len).max()
genres_len = basics_genres['genres_split'].fillna('').map(len).max()
# Create a schema dictonary using Sqlalchemy datatype objects
df_schema_genres = {
    "tconst": Text(key_len+1), 
    "genres_split": Text(title_len+1)}

# %% [markdown]
# ### Saving with to_sql()

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
ratings.to_sql('title_ratings',engine,dtype=df_schema_ratings,if_exists='replace',index=False)
tmdb_api.to_sql('tmdb_data',engine,dtype=df_schema_tmdb,if_exists='replace',index=False)
basics_genres.to_sql('title_genres',engine,dtype=df_schema_genres,if_exists='replace',index=False)
## Set the dataframe index and use index=True for genre
genres.set_index('genre_id').to_sql('genres',engine,if_exists='replace',index=True)
# Out:
# 26

# %% [markdown]
# Now I will run the following query to add the primary key.

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')
engine.execute('ALTER TABLE genres ADD PRIMARY KEY (`genre_id`);')

# %% [markdown]
# ## View Created Tables

# %%
q = """SHOW TABLES"""

df = pd.read_sql_query(q, engine)
df
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4        tmdb_data
