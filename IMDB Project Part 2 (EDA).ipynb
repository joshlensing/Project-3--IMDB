# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# ## Load Datasets

# %%
df_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %% [markdown]
# ## Concatenate DataFrames

# %%
combined_df = pd.concat([df_2000, df_2001], ignore_index=True)
combined_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 2521  tt7797670    0.0                               NaN
# 2522  tt7797790    0.0                               NaN
# 2523  tt8665056    0.0                               NaN
# 2524  tt8795764    0.0                               NaN
# 2525  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...

# %% [markdown]
# ### Make a Copy of the DataFrame

# %%
eda_df = combined_df.copy()

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Filtering the DataFrame
#
# I want to know what movies generated revenue greater than zero or had any budget at all. To do this I will filter the combined_df for movies that were greater than zero in both features.

# %%
revenue_filter = eda_df['revenue'] > 0
eda_df = eda_df.loc[revenue_filter,:]
eda_df.head()
# Out:
#       imdb_id  adult                     backdrop_path  \
# 4   tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 10  tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 11  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 13  tt0120630    0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 16  tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
#
#                                 belongs_to_collection      budget  \
# 4                                                 NaN    150000.0
# 10                                                NaN         0.0
# 11                                                NaN    120000.0
# 13  {'id': 718551, 'name': 'Chicken Run Collection...  45000000.0
# 16                                                NaN   8000000.0
#
#                                                genres homepage       id  \
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    843.0
# 10  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  34070.0
# ...

# %% [markdown]
# The first question that I want to answer with visuals is how many movies generated revenue. I can do that with the filter I created above.

# %%
plt.style.use('seaborn')
eda_df['revenue'].hist(bins = 30, edgecolor='black')
plt.xlabel('Total Revenue')
plt.ylabel('Count')
plt.title('Revenue Counts for Movies')
plt.xticks(rotation = 45)
plt.ticklabel_format(useOffset=False, style='plain');
# Out:
# C:\Users\joshl\AppData\Local\Temp\ipykernel_13796\1387243016.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# Most of the movies in the dataset that generated revenue seemed to generate $200 million or less.

# %% [markdown]
# ### Filter out Movies with a zero Budget
#
# For the rest of the dataset, I want to create visuals for movies that also had greater than zero budget. I will create another filter for that as well and update the DataFrame.

# %%
budget_filter = eda_df['budget'] > 0
eda_df = eda_df.loc[revenue_filter & budget_filter,:]
eda_df.head()
# Out:
#       imdb_id  adult                     backdrop_path  \
# 4   tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 11  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 13  tt0120630    0.0  /t7aJ7hqsMLEoqBJk7yAXxcAVvcz.jpg
# 16  tt0120753    0.0  /3vUkQpnwbsFEQlMh9EORpvKJfpo.jpg
# 17  tt0120755    0.0  /24DZfupDlhXeTchmcOkoGRhP5Vg.jpg
#
#                                 belongs_to_collection       budget  \
# 4                                                 NaN     150000.0
# 11                                                NaN     120000.0
# 13  {'id': 718551, 'name': 'Chicken Run Collection...   45000000.0
# 16                                                NaN    8000000.0
# 17  {'id': 87359, 'name': 'Mission: Impossible Col...  125000000.0
#
#                                                genres homepage       id  \
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    843.0
# 11  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN  19085.0
# ...

# %% [markdown]
# ### Number of Movies in Each Certification Category
#
# Now I want to visualize the number of movies in each certification category.

# %%
sns.countplot(data=eda_df, x='certification', 
              order=['G', 'PG', 'PG-13', 'R', 'NR']);

# %% [markdown]
# From the countplot, it looks like R-rated movies were the highest number of movies while NR movies were the lowest.

# %% [markdown]
# ### Average Revenue per Certification
#
# An important piece of information to visualize is the amount of revenue generated by the different certification categories to understand what kind of movies generate the most amount of money.

# %%
# using groupby to get the average revenue
avg_rev = eda_df.groupby(['certification'])['revenue'].mean().sort_values(ascending=False)
avg_rev
# Out:
# certification
# G        1.332169e+08
# PG       1.262966e+08
# PG-13    1.110740e+08
# R        5.294547e+07
# NR       2.212257e+07
# Name: revenue, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,8))
avg_rev.plot.bar()

price_fmt = mpl.ticker.StrMethodFormatter('${x:,.0f}')
ax.yaxis.set_major_formatter(price_fmt)

# %% [markdown]
# Even though G-rated movies were not as populace in the dataset, the average revenue was the greatest generated.

# %% [markdown]
# ### Average Budget per Certification
#
# On the flip side of revenue, I also want to visualize how the budget for each certification category differs. This can then be compared to the revenue to get a generalization of what the net profits are.

# %%
# using groupby again to find the average
avg_bud = eda_df.groupby(['certification'])['budget'].mean().sort_values(ascending=False)
avg_bud
# Out:
# certification
# PG       5.062088e+07
# PG-13    4.664442e+07
# G        4.400000e+07
# R        2.706348e+07
# NR       1.352857e+07
# Name: budget, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,8))
avg_bud.plot.bar()

price_fmt = mpl.ticker.StrMethodFormatter('${x:,.0f}')
ax.yaxis.set_major_formatter(price_fmt)

# %% [markdown]
# PG-rated movies appeared to have the highest budget on average, even though it only generated the second-highest revenue.

# %% [markdown]
# ## Saving the Combined Datasets
#
# I want to save the combined datasets and save them as a csv.gz to use for future work in the project.

# %%
combined_df.to_csv(f"Data/tmdb_results_combined.csv.gz", compression="gzip", index=False)
